# %%
import json
import numpy as np
import pandas as pd

# %%
# Abrir o arquivo de tweets e ler as linhas
with open('collected_tweets2020-49-01-20-49-31.txt','r') as file:
    tweets = file.readlines()

# %%
# Fazendo parsens e escrevendo novo arquivo JSON
# with open('tweet.json','w') as f:
#     json.dump(
#         json.loads(json.loads(tweets[0])),f
#     )

# %%
# Tipo dos nossos dados
type(
    json.loads(
        json.loads(tweets[0])
    )    
)
# Out:
# dict

# %% [markdown]
# # Acessando as chaves JSON (Dicionário)

# %%
parsed_tweets = [json.loads(json.loads(i)) for i in tweets]

# %%
# parsed_tweets[1]

# %%
# Numero de linhas 
len(parsed_tweets)
# Out:
# 53466

# %%
primeiro_tweet = parsed_tweets[0]

# %%
list(primeiro_tweet.items())[1]
# Out:
# ('id', 1333921183415189505)

# %%
primeiro_tweet.keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'display_text_range', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'extended_tweet', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])

# %%
# acessando texto do tweet, chave de primeiro nivel (root)
primeiro_tweet['text']
# Out:
# '@DailyCaller @MariaBartiromo Aren’t most journalists knowledgeable in laws and reality of another’s interpretation… https://t.co/GKlfCTWvzf'

# %%
primeiro_tweet['user']
# Out:
# {'id': 1050224102126964737,
#  'id_str': '1050224102126964737',
#  'name': 'WeAreAllGoodPeople,Not',
#  'screen_name': 'cmebmebhappy',
#  'location': 'Possibly somewhere up high ',
#  'url': None,
#  'description': 'Just like to hear many different views. It is great to interact.I have lots of opinions. Liberal. Unity. #Biden2020 #ByeDon #MoscowMitch',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 509,
#  'friends_count': 501,
#  'listed_count': 0,
#  'favourites_count': 2424,
#  'statuses_count': 2962,
#  'created_at': 'Thu Oct 11 03:18:32 +0000 2018',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': False,
#  'lang': None,
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': '',
#  'profile_background_image_url_https': '',
#  'profile_background_tile': False,
#  'profile_link_color': '1DA1F2',
# ...

# %%
primeiro_tweet['user']['screen_name']
# Out:
# 'cmebmebhappy'

# %% [markdown]
# # Transformar os tweets em uma estrutura relacional analisável

# %%
df_tratado = pd.DataFrame(parsed_tweets[1]).reset_index(drop=True).iloc[:1]
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Dec 01 23:49:27 +0000 2020  1333921183503355904  1333921183503355904
#
#                                                 text  \
# 0  RT @chiIIum: Don’t you dare give up on Preside...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ... quote_count reply_count retweet_count  \
# 0                    None  ...           0           0             0
#
#   favorite_count entities favorited retweeted  filter_level  lang  \
# 0              0      NaN     False     False           low    en
#
#     timestamp_ms
# 0  1606866567861
#
# [1 rows x 28 columns]

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place',
#        'contributors', 'retweeted_status', 'is_quote_status', 'quote_count',
#        'reply_count', 'retweet_count', 'favorite_count', 'entities',
#        'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'],
#       dtype='object')

# %%
df_tratado.drop(columns=['quote_count','reply_count', 'retweet_count', 
                         'favorite_count','favorited', 'retweeted',
                        'user', 'retweeted_status','entities'], inplace=True)

# %%
df_tratado.columns
# Out:
# Index(['created_at', 'id', 'id_str', 'text', 'source', 'truncated',
#        'in_reply_to_status_id', 'in_reply_to_status_id_str',
#        'in_reply_to_user_id', 'in_reply_to_user_id_str',
#        'in_reply_to_screen_name', 'geo', 'coordinates', 'place',
#        'contributors', 'is_quote_status', 'filter_level', 'lang',
#        'timestamp_ms'],
#       dtype='object')

# %%
df_tratado['user_id'] = parsed_tweets[1]['user']['id']
df_tratado['user_id_str'] = parsed_tweets[1]['user']['id_str']
df_tratado['user_screen_name'] = parsed_tweets[1]['user']['screen_name']
df_tratado['user_location'] = parsed_tweets[1]['user']['location']
df_tratado['user_description'] = parsed_tweets[1]['user']['description']
df_tratado['user_protected'] = parsed_tweets[1]['user']['protected']
df_tratado['user_verified'] = parsed_tweets[1]['user']['verified']
df_tratado['user_followers_count'] = parsed_tweets[1]['user']['followers_count']
df_tratado['user_friends_count'] = parsed_tweets[1]['user']['friends_count']
df_tratado['user_created_at'] = parsed_tweets[1]['user']['created_at']

# %%
df_tratado
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Dec 01 23:49:27 +0000 2020  1333921183503355904  1333921183503355904
#
#                                                 text  \
# 0  RT @chiIIum: Don’t you dare give up on Preside...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...             user_id         user_id_str  \
# 0                    None  ...  875922981733548032  875922981733548032
#
#   user_screen_name user_location  \
# 0  HollySh43407891          None
#
#                                     user_description  user_protected  \
# 0  American Patriot, Conservative, Christian, TRU...           False
#
#   user_verified user_followers_count user_friends_count  \
# ...

# %%
# Entidades
parsed_tweets[1]['entities']
# Out:
# {'hashtags': [],
#  'urls': [],
#  'user_mentions': [{'screen_name': 'chiIIum',
#    'name': '𝕔hi𝓁𝓁iຖ໐iˢ',
#    'id': 466183294,
#    'id_str': '466183294',
#    'indices': [3, 11]}],
#  'symbols': []}

# %%
user_mentions = []

for i in range(len(parsed_tweets[1]['entities']['user_mentions'])):
    dict_base = parsed_tweets[1]['entities']['user_mentions'][i].copy()
    dict_base.pop('indices', None)
    df = pd.DataFrame(dict_base, index=[0])
    df = df.rename(columns={
        'screen_name': 'entites_screen_name',
        'name': 'entites_id',
        'id_str': 'entites_id_str'
    })
    user_mentions.append(df)

# %%
user_mentions
# Out:
# [  entites_screen_name  entites_id         id entites_id_str
#  0             chiIIum  𝕔hi𝓁𝓁iຖ໐iˢ  466183294      466183294]

# %%
dfs = []

for i in user_mentions:
    dfs.append(
        pd.concat([df_tratado.copy(), i], axis=1)
    )

# %%
dfs
# Out:
# [                       created_at                   id               id_str  \
#  0  Tue Dec 01 23:49:27 +0000 2020  1333921183503355904  1333921183503355904
#
#                                                  text  \
#  0  RT @chiIIum: Don’t you dare give up on Preside...
#
#                                                source  truncated  \
#  0  <a href="http://twitter.com/download/iphone" r...      False
#
#    in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
#  0                  None                      None                None
#
#    in_reply_to_user_id_str  ...  \
#  0                    None  ...
#
#                                      user_description user_protected  \
#  0  American Patriot, Conservative, Christian, TRU...          False
#
#    user_verified user_followers_count user_friends_count  \
#  0         False                  381               1065
#
#                    user_created_at entites_screen_name  entites_id         id  \
# ...

# %%
pd.concat(dfs, ignore_index=True)
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Dec 01 23:49:27 +0000 2020  1333921183503355904  1333921183503355904
#
#                                                 text  \
# 0  RT @chiIIum: Don’t you dare give up on Preside...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...  \
# 0                    None  ...
#
#                                     user_description user_protected  \
# 0  American Patriot, Conservative, Christian, TRU...          False
#
#   user_verified user_followers_count user_friends_count  \
# 0         False                  381               1065
#
#                   user_created_at entites_screen_name  entites_id         id  \
# ...

# %% [markdown]
#    # Vamos criar uma função que converter tweets para um DataFrame

# %%
def tweets_para_df(tweet):
    try:
        df_tratado = pd.DataFrame(tweet).reset_index(drop=True).iloc[:1]

        df_tratado.drop(columns=['quote_count','reply_count', 'retweet_count', 
                                 'favorite_count','favorited', 'retweeted', 'user',
                                 'retweeted_status','entities'], inplace=True)

        df_tratado['user_id'] = tweet['user']['id']
        df_tratado['user_id_str'] = tweet['user']['id_str']
        df_tratado['user_screen_name'] = tweet['user']['screen_name']
        df_tratado['user_location'] = tweet['user']['location']
        df_tratado['user_description'] = tweet['user']['description']
        df_tratado['user_protected'] = tweet['user']['protected']
        df_tratado['user_verified'] = tweet['user']['verified']
        df_tratado['user_followers_count'] = tweet['user']['followers_count']
        df_tratado['user_friends_count'] = tweet['user']['friends_count']
        df_tratado['user_created_at'] = tweet['user']['created_at']

        user_mentions = []

        for i in range(len(tweet['entities']['user_mentions'])):
            dict_base = tweet['entities']['user_mentions'][i].copy()
            dict_base.pop('indices', None)
            df = pd.DataFrame(dict_base, index=[0])
            df = df.rename(columns={
                'screen_name': 'entites_screen_name',
                'name': 'entites_id',
                'id_str': 'entites_id_str'
            })
            user_mentions.append(df)

        dfs = []

        for i in user_mentions:
            dfs.append(pd.concat([df_tratado.copy(), i], axis=1))
            
        df_final = pd.concat(dfs, ignore_index=True)
    
    except:    
        return None
    
    return df_final

# %%
tweets_para_df(parsed_tweets[6])
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Dec 01 23:49:27 +0000 2020  1333921183885127680  1333921183885127680
# 1  Tue Dec 01 23:49:27 +0000 2020  1333921183885127680  1333921183885127680
#
#                                                 text  \
# 0  RT @maggieNYT: .@abc confirms our story on Giu...
# 1  RT @maggieNYT: .@abc confirms our story on Giu...
#
#                                               source  truncated  \
# 0  <a href="http://twitter.com/download/iphone" r...      False
# 1  <a href="http://twitter.com/download/iphone" r...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
# 1                  None                      None                None
#
#   in_reply_to_user_id_str  ...  \
# 0                    None  ...
# 1                    None  ...
#
# ...

# %%
# %%time
# Vamos iterar e transformar todos os tweets
parseados = [tweets_para_df(tweet) for tweet in parsed_tweets]
# Out:
# CPU times: user 15min 3s, sys: 1.33 s, total: 15min 4s
# Wall time: 15min 3s

# %%
#Eliminar as posições vazias da lista 
parseados = [i for i in parseados if i is not None]

# %%
parseados[10]
# Out:
#                        created_at                   id               id_str  \
# 0  Tue Dec 01 23:49:28 +0000 2020  1333921184442851328  1333921184442851328
#
#                                                 text  \
# 0  RT @news_ntd: "I find it highly implausible be...
#
#                                               source  truncated  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...      False
#
#   in_reply_to_status_id in_reply_to_status_id_str in_reply_to_user_id  \
# 0                  None                      None                None
#
#   in_reply_to_user_id_str  ...  \
# 0                    None  ...
#
#                                  user_description user_protected  \
# 0  Love reading, dogs, baking, sleep, and helping          False
#
#   user_verified user_followers_count user_friends_count  \
# 0         False                   35                 71
#
#                   user_created_at entites_screen_name entites_id  \
# ...

# %%
tratado = pd.concat(parseados[:10], ignore_index=True)

# %%
tratado
# Out:
#                         created_at                   id               id_str  \
# 0   Tue Dec 01 23:49:27 +0000 2020  1333921183503355904  1333921183503355904
# 1   Tue Dec 01 23:49:27 +0000 2020  1333921183763476482  1333921183763476482
# 2   Tue Dec 01 23:49:27 +0000 2020  1333921183792730112  1333921183792730112
# 3   Tue Dec 01 23:49:27 +0000 2020  1333921183880912896  1333921183880912896
# 4   Tue Dec 01 23:49:27 +0000 2020  1333921183885127680  1333921183885127680
# 5   Tue Dec 01 23:49:27 +0000 2020  1333921183885127680  1333921183885127680
# 6   Tue Dec 01 23:49:27 +0000 2020  1333921183968976896  1333921183968976896
# 7   Tue Dec 01 23:49:28 +0000 2020  1333921184157667333  1333921184157667333
# 8   Tue Dec 01 23:49:28 +0000 2020  1333921184325492742  1333921184325492742
# 9   Tue Dec 01 23:49:28 +0000 2020  1333921184447041537  1333921184447041537
# 10  Tue Dec 01 23:49:28 +0000 2020  1333921184350695429  1333921184350695429
#
# ...

# %% [markdown]
# # Ingestão de dados do Twitter no POSTGRESQL

# %%
import io
from sqlalchemy import create_engine
import psycopg2

# %%
engine = create_engine('postgresql://postgres:1234@127.0.0.1/twitter')

# %%
tratado.to_sql("tweet", con=engine, index=False, if_exists="append")
